# %%
import numpy as np
from plotting.fancy_distribution_plot import fancy_distribution_plot

# %%
# Create example random data
np.random.seed(0)
distro1 = np.random.normal(0, 2, 4)
distr2 = np.random.normal(1, 1, 10)
distr3 = np.random.normal(2, 3, 20)

distributions = [ distr3]
fancy_distribution_plot(distributions, tick_labels=[ 'distro3'], number_of_segments=2,
                        grid=False)
